# %% [markdown]
# # Store Profile Classifier

# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
transactions = pd.read_csv("/kaggle/input/dataset/Historical-transaction-data.csv")
storedata = pd.read_csv("/kaggle/input/dataset/Store-info.csv")
testdata = pd.read_csv("/kaggle/input/dataset/Testing-data.csv")

# %%
transactions.head()
# Out:
#         item_description          transaction_date  invoice_id customer_id  \
# 0     ORANGE BARLEY 1.5L  2021-12-11T00:00:00.000Z       147.0        BGXA
# 1       GINGER BEER 1.5L  2021-10-17T00:00:00.000Z       371.0        IA25
# 2        TONIC PET 500ML  2021-12-13T00:00:00.000Z       484.0        VN7V
# 3          CREAM SODA 1L  2021-12-13T00:00:00.000Z       484.0        VN7V
# 4  STRAWBERRY MILK 180ML  2021-10-23T00:00:00.000Z      1310.0        7S00
#
#    shop_id  item_price  quantity_sold
# 0  SHOP008         220              2
# 1  SHOP112         220              2
# 2  SHOP008         160              2
# 3  SHOP008         150              2
# 4  SHOP112         210              5

# %%
unique_shops = transactions['shop_id'].nunique()
print(unique_shops)
# Out:
# 124

# %% [markdown]
# Basically there are 124 shops in total, we'll create a dataset from the transaction data

# %%
storedata
# Out:
#      shop_id  shop_area_sq_ft shop_profile
# 0    SHOP047              528     Moderate
# 1    SHOP009              676         High
# 2    SHOP083              676          Low
# 3    SHOP117              676          Low
# 4    SHOP042              676          Low
# ..       ...              ...          ...
# 119  SHOP087              527          NaN
# 120  SHOP050              411          NaN
# 121  SHOP061              699          NaN
# 122  SHOP056              597          NaN
# 123  SHOP070              676          NaN
#
# [124 rows x 3 columns]

# %% [markdown]
# # Planned Features
# ### Implemented
# - Total Sales volume (total_vol)
# - Total number of unique customers (total_customers)
#
# ### Not yet implemented
# - Largest volume by date? Largest volume in a single day (single_day_max_vol) ?
# - Smallest volume by date?
# - Sales volume per square foot
# - Number of recurring customers
#
# ### Target variable is shop_profile

# %% [markdown]
# ## Adding total_vol and vol_per_sq_ft

# %%
# Compute the total volume of transactions for each store_id in the dataset dataframe
total_vol_by_store = transactions.groupby('shop_id').apply(lambda x: (x['item_price'] * x['quantity_sold']).sum())

total_vol_by_store = total_vol_by_store.rename('total_vol')

# Merge the total_vol_by_store series with the storedata dataframe on the 'store_id' column
storedata = pd.merge(storedata, total_vol_by_store, on='shop_id', how='left')
storedata["vol_per_sq_ft"] = storedata["total_vol"] / storedata["shop_area_sq_ft"]
storedata
# Out:
#      shop_id  shop_area_sq_ft shop_profile  total_vol  vol_per_sq_ft
# 0    SHOP047              528     Moderate     842960    1596.515152
# 1    SHOP009              676         High    1970870    2915.488166
# 2    SHOP083              676          Low    1691985    2502.936391
# 3    SHOP117              676          Low    2325980    3440.798817
# 4    SHOP042              676          Low    1340215    1982.566568
# ..       ...              ...          ...        ...            ...
# 119  SHOP087              527          NaN    1128935    2142.191651
# 120  SHOP050              411          NaN    2399125    5837.287105
# 121  SHOP061              699          NaN    2110800    3019.742489
# 122  SHOP056              597          NaN    3023805    5065.000000
# 123  SHOP070              676          NaN    1325070    1960.162722
#
# [124 rows x 5 columns]

# %% [markdown]
# ## Adding total_customers

# %%
# group the transactions dataframe by shop_id and count the number of unique customer_ids
unique_customers = transactions.groupby('shop_id')['customer_id'].nunique()

# add a new column to the storedata dataframe with the counts of unique customers
storedata['total_customers'] = storedata['shop_id'].map(unique_customers)

# %%
storedata
# Out:
#      shop_id  shop_area_sq_ft shop_profile  total_vol  vol_per_sq_ft  \
# 0    SHOP047              528     Moderate     842960    1596.515152
# 1    SHOP009              676         High    1970870    2915.488166
# 2    SHOP083              676          Low    1691985    2502.936391
# 3    SHOP117              676          Low    2325980    3440.798817
# 4    SHOP042              676          Low    1340215    1982.566568
# ..       ...              ...          ...        ...            ...
# 119  SHOP087              527          NaN    1128935    2142.191651
# 120  SHOP050              411          NaN    2399125    5837.287105
# 121  SHOP061              699          NaN    2110800    3019.742489
# 122  SHOP056              597          NaN    3023805    5065.000000
# 123  SHOP070              676          NaN    1325070    1960.162722
#
#      total_customers
# 0                928
# 1               2498
# 2               1900
# 3               2037
# 4               1841
# ..               ...
# 119             1083
# 120             1778
# 121             1746
# 122             2832
# 123             1423
#
# [124 rows x 6 columns]

# %% [markdown]
# ## Adding single_day_max_vol

# %%
# assuming the transactions dataframe is already defined
transactions['single_day_max_vol'] = transactions['item_price'] * transactions['quantity_sold']
total_volume_per_day = transactions.groupby(['shop_id', 'transaction_date'])['single_day_max_vol'].sum().reset_index()
highest_volume_per_shop = total_volume_per_day.groupby('shop_id')['single_day_max_vol'].max().reset_index()

storedata = pd.merge(storedata, highest_volume_per_shop, on='shop_id')

# %% [markdown]
# ## Adding single_day_min_vol

# %%
# assuming the transactions dataframe is already defined
transactions['single_day_min_vol'] = transactions['item_price'] * transactions['quantity_sold']
total_volume_per_day = transactions.groupby(['shop_id', 'transaction_date'])['single_day_min_vol'].sum().reset_index()
highest_volume_per_shop = total_volume_per_day.groupby('shop_id')['single_day_min_vol'].min().reset_index()

storedata = pd.merge(storedata, highest_volume_per_shop, on='shop_id')

# %%
storedata
# Out:
#      shop_id  shop_area_sq_ft shop_profile  total_vol  vol_per_sq_ft  \
# 0    SHOP047              528     Moderate     842960    1596.515152
# 1    SHOP009              676         High    1970870    2915.488166
# 2    SHOP083              676          Low    1691985    2502.936391
# 3    SHOP117              676          Low    2325980    3440.798817
# 4    SHOP042              676          Low    1340215    1982.566568
# ..       ...              ...          ...        ...            ...
# 119  SHOP087              527          NaN    1128935    2142.191651
# 120  SHOP050              411          NaN    2399125    5837.287105
# 121  SHOP061              699          NaN    2110800    3019.742489
# 122  SHOP056              597          NaN    3023805    5065.000000
# 123  SHOP070              676          NaN    1325070    1960.162722
#
#      total_customers  single_day_max_vol  single_day_min_vol
# 0                928               71305                2020
# 1               2498               85750                9230
# 2               1900               70610                8225
# 3               2037               82170                6390
# 4               1841               69185                5265
# ..               ...                 ...                 ...
# 119             1083              119750                2160
# 120             1778              157410                8015
# 121             1746              475215                6495
# 122             2832              162465               16780
# 123             1423               84500                5495
#
# [124 rows x 8 columns]

# %% [markdown]
# ## Checking Correlation

# %%
# create a correlation matrix
corr_matrix = storedata.corr()

# create a heatmap of the correlation matrix
sns.heatmap(corr_matrix, cmap="coolwarm", annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Train test split (basically removing the testing data specified)

# %%
# Create a boolean mask for filtering shopdata
mask = storedata['shop_id'].isin(testdata['shop_id'])

# Create two separate dataframes
test_shops = storedata[mask]
train_shops = storedata[~mask]

# %%
test_shops = test_shops.drop('shop_profile', axis=1)
test_shops
# Out:
#      shop_id  shop_area_sq_ft  total_vol  vol_per_sq_ft  total_customers  \
# 100  SHOP046              545    2607865    4785.073394             1736
# 101  SHOP024              676    1308795    1936.087278             1641
# 102  SHOP023              617    2570425    4166.004862             2227
# 103  SHOP097              310    2642380    8523.806452             1669
# 104  SHOP044              715    1310440    1832.783217             1552
# 105  SHOP030              530    2862995    5401.877358             1637
# 106  SHOP038              411    1444025    3513.442822             1781
# 107  SHOP029              597    1973805    3306.206030             2052
# 108  SHOP096              676    2600915    3847.507396             2497
# 109  SHOP092              617    1961240    3178.670989             2247
# 110  SHOP081              774    2067720    2671.472868             1985
# 111  SHOP076              676    2276575    3367.714497             1992
# 112  SHOP080              554    1322790    2387.707581             1268
# 113  SHOP074              617    2608740    4228.103728             2738
# 114  SHOP107              588    2565235    4362.644558              921
# 115  SHOP108              676    2100715    3107.566568             2077
# 116  SHOP019              411    2200580    5354.209246             1922
# 117  SHOP002              637    3084455    4842.158556             2577
# 118  SHOP114              513    2131345    4154.668616             2480
# 119  SHOP087              527    1128935    2142.191651             1083
# 120  SHOP050              411    2399125    5837.287105             1778
# 121  SHOP061              699    2110800    3019.742489             1746
# 122  SHOP056              597    3023805    5065.000000             2832
# 123  SHOP070              676    1325070    1960.162722             1423
#
#      single_day_max_vol  single_day_min_vol
# 100              416450                9805
# 101               63695                6210
# 102              179010               11240
# 103              379995                9530
# 104               83410                5465
# 105              255825                5845
# 106               84285                5045
# 107               79130                8220
# 108              221065                8605
# 109              250855               11600
# 110              378050                8590
# 111              215975                6320
# 112              148920                2130
# 113              133130               15690
# 114              262085                4250
# 115              203600                6760
# 116              126685                4630
# 117              170700                8665
# 118              185500                6060
# 119              119750                2160
# 120              157410                8015
# 121              475215                6495
# 122              162465               16780
# 123               84500                5495

# %%
train_shops
# Out:
#     shop_id  shop_area_sq_ft shop_profile  total_vol  vol_per_sq_ft  \
# 0   SHOP047              528     Moderate     842960    1596.515152
# 1   SHOP009              676         High    1970870    2915.488166
# 2   SHOP083              676          Low    1691985    2502.936391
# 3   SHOP117              676          Low    2325980    3440.798817
# 4   SHOP042              676          Low    1340215    1982.566568
# ..      ...              ...          ...        ...            ...
# 95  SHOP124              606         High    2967190    4896.353135
# 96  SHOP012              336          Low    1169405    3480.372024
# 97  SHOP093              705         High    1726515    2448.957447
# 98  SHOP004              516          Low    1571700    3045.930233
# 99  SHOP101              691         High    2465930    3568.639653
#
#     total_customers  single_day_max_vol  single_day_min_vol
# 0               928               71305                2020
# 1              2498               85750                9230
# 2              1900               70610                8225
# 3              2037               82170                6390
# 4              1841               69185                5265
# ..              ...                 ...                 ...
# 95             2281              409990               14510
# 96             1263              181610                2900
# 97             1493              367595                4145
# 98             1744               67275                6285
# 99             2695               95935               10055
#
# [100 rows x 8 columns]

# %% [markdown]
# ## Encoding the target variable
#
# ### Ordinal encoding
# 0 = Low
# 1 = Moderate
# 2 = High

# %%
from sklearn.preprocessing import LabelEncoder
pd.options.mode.chained_assignment = None  # default='warn'

# Define the mapping of labels to integer codes
label_mapping = {
    'Low': 0,
    'Moderate': 1,
    'High': 2
}

# Create an instance of the LabelEncoder
encoder = LabelEncoder()

# Fit the encoder to the shop_profile column in train_shops
train_shops['shop_profile'] = encoder.fit_transform(train_shops['shop_profile'].map(label_mapping))

# %%
train_shops
# Out:
#     shop_id  shop_area_sq_ft  shop_profile  total_vol  vol_per_sq_ft  \
# 0   SHOP047              528             1     842960    1596.515152
# 1   SHOP009              676             2    1970870    2915.488166
# 2   SHOP083              676             0    1691985    2502.936391
# 3   SHOP117              676             0    2325980    3440.798817
# 4   SHOP042              676             0    1340215    1982.566568
# ..      ...              ...           ...        ...            ...
# 95  SHOP124              606             2    2967190    4896.353135
# 96  SHOP012              336             0    1169405    3480.372024
# 97  SHOP093              705             2    1726515    2448.957447
# 98  SHOP004              516             0    1571700    3045.930233
# 99  SHOP101              691             2    2465930    3568.639653
#
#     total_customers  single_day_max_vol  single_day_min_vol
# 0               928               71305                2020
# 1              2498               85750                9230
# 2              1900               70610                8225
# 3              2037               82170                6390
# 4              1841               69185                5265
# ..              ...                 ...                 ...
# 95             2281              409990               14510
# 96             1263              181610                2900
# 97             1493              367595                4145
# 98             1744               67275                6285
# 99             2695               95935               10055
#
# [100 rows x 8 columns]

# %%
sns.pairplot(train_shops, hue='shop_profile')

# %% [markdown]
# ## Spliting for crossvalidation

# %%
y = train_shops['shop_profile']
X = train_shops.drop('shop_profile', axis=1)
X = X.drop('shop_id',axis = 1)

# %%
y
# Out:
# 0     1
# 1     2
# 2     0
# 3     0
# 4     0
#      ..
# 95    2
# 96    0
# 97    2
# 98    0
# 99    2
# Name: shop_profile, Length: 100, dtype: int64

# %%
X
# Out:
#     shop_area_sq_ft  total_vol  vol_per_sq_ft  total_customers  \
# 0               528     842960    1596.515152              928
# 1               676    1970870    2915.488166             2498
# 2               676    1691985    2502.936391             1900
# 3               676    2325980    3440.798817             2037
# 4               676    1340215    1982.566568             1841
# ..              ...        ...            ...              ...
# 95              606    2967190    4896.353135             2281
# 96              336    1169405    3480.372024             1263
# 97              705    1726515    2448.957447             1493
# 98              516    1571700    3045.930233             1744
# 99              691    2465930    3568.639653             2695
#
#     single_day_max_vol  single_day_min_vol
# 0                71305                2020
# 1                85750                9230
# 2                70610                8225
# 3                82170                6390
# 4                69185                5265
# ..                 ...                 ...
# 95              409990               14510
# 96              181610                2900
# 97              367595                4145
# 98               67275                6285
# 99               95935               10055
#
# [100 rows x 6 columns]

# %% [markdown]
# ### Train test split

# %%
from sklearn.model_selection import train_test_split
train_X, val_X, train_y, val_y = train_test_split(X, y, random_state = 0)

# %% [markdown]
# ## Training the model

# %%
train_X
# Out:
#     shop_area_sq_ft  total_vol  vol_per_sq_ft  total_customers  \
# 48              720     931695    1294.020833             1370
# 6               617    2946220    4775.072934             2496
# 99              691    2465930    3568.639653             2695
# 82              605    1917850    3170.000000             1894
# 76              617    3606120    5844.602917             2959
# ..              ...        ...            ...              ...
# 96              336    1169405    3480.372024             1263
# 67              520    2206435    4243.144231             2172
# 64              617    2671250    4329.416532             2474
# 47              617    1791290    2903.225284             1678
# 44              617    2198800    3563.695300             2417
#
#     single_day_max_vol  single_day_min_vol
# 48               39190                6060
# 6               136070                8755
# 99               95935               10055
# 82              168610                7515
# 76              180995               13400
# ..                 ...                 ...
# 96              181610                2900
# 67              130890                5130
# 64              510175               11135
# 47              261945                4080
# 44              126355               10740
#
# [75 rows x 6 columns]

# %%
train_y
# Out:
# 48    1
# 6     1
# 99    2
# 82    1
# 76    2
#      ..
# 96    0
# 67    0
# 64    2
# 47    1
# 44    1
# Name: shop_profile, Length: 75, dtype: int64

# %%
val_X
# Out:
#     shop_area_sq_ft  total_vol  vol_per_sq_ft  total_customers  \
# 26              594    1543645    2598.728956             1920
# 86              441    1640080    3719.002268             1591
# 2               676    1691985    2502.936391             1900
# 55              661    2697370    4080.741301             3164
# 75              549    2694095    4907.276867             3007
# 93              555    3220950    5803.513514             2336
# 16              495    2157105    4357.787879             3081
# 73              541    1832065    3386.441774             1603
# 54              617    2828540    4584.343598             2362
# 95              606    2967190    4896.353135             2281
# 53              709    2126605    2999.442877             2671
# 92              565    1970175    3487.035398             2075
# 78              422    2663785    6312.286730             2073
# 13              537    1637380    3049.124767             1492
# 7               423    1607630    3800.543735             1328
# 30             1077    3734470    3467.474466             3091
# 22              709    2057905    2902.545839             2661
# 24              517    1272710    2461.721470             1204
# 33              441    1727280    3916.734694             1641
# 8               676    2525525    3735.983728             2055
# 43              706    1707520    2418.583569             1368
# 62              810    1922995    2374.067901             2064
# 3               676    2325980    3440.798817             2037
# 71              617    2988550    4843.679092             2435
# 45              617    1785495    2893.833063             2046
#
#     single_day_max_vol  single_day_min_vol
# 26              106095                8060
# 86              122105                4610
# 2                70610                8225
# 55              210680               15515
# 75              100090               17610
# 93              211115               11790
# 16               95865               12020
# 73              142890                4930
# 54              120770               11190
# 95              409990               14510
# 53               94560               10950
# 92               87265                8850
# 78              190960                6500
# 13              132845                3390
# 7                88185                6260
# 30              248655               18945
# 22               99560                9525
# 24               68110                2495
# 33              101370                4610
# 8               173450                9570
# 43              104270                2545
# 62               98890                6225
# 3                82170                6390
# 71              244925                9180
# 45              114750                9580

# %%
val_y
# Out:
# 26    1
# 86    1
# 2     0
# 55    2
# 75    2
# 93    2
# 16    2
# 73    1
# 54    1
# 95    2
# 53    2
# 92    0
# 78    1
# 13    1
# 7     1
# 30    2
# 22    2
# 24    0
# 33    0
# 8     0
# 43    1
# 62    2
# 3     0
# 71    1
# 45    0
# Name: shop_profile, dtype: int64

# %% [markdown]
# ### Training model

# %%
from sklearn.neighbors import KNeighborsClassifier
from xgboost import XGBClassifier
from sklearn.ensemble import RandomForestClassifier

# %%
# Define the model with default hyperparameters
# model = XGBClassifier()
# model = KNeighborsClassifier(n_neighbors= 25)
model = RandomForestClassifier(n_estimators=100,random_state=1)

# Fit the model to the training data
model.fit(train_X, train_y)
# Out:
# RandomForestClassifier(random_state=1)

# %% [markdown]
# ## Making predictions

# %%
# Make predictions on the test data
y_pred = model.predict(val_X)

# %% [markdown]
# ## F1 Score

# %%
from sklearn.metrics import f1_score

# Calculate the F1 score
f1 = f1_score(val_y, y_pred,average='micro')

# Print the result
print("F1 score:", f1)
# Out:
# F1 score: 0.6

# %% [markdown]
# ## For submissions Train using full X and y sets

# %%
# Define the model with default hyperparameters
# FinalModel = XGBClassifier()
# FinalModel = KNeighborsClassifier(n_neighbors=3)
FinalModel = RandomForestClassifier(n_estimators=100,random_state=1)

# Fit the model to the training data
FinalModel.fit(train_X, train_y)
# Out:
# RandomForestClassifier(random_state=1)

# %%
test_shops = test_shops.drop('shop_id', axis=1)
test_shops
# Out:
#      shop_area_sq_ft  total_vol  vol_per_sq_ft  total_customers  \
# 100              545    2607865    4785.073394             1736
# 101              676    1308795    1936.087278             1641
# 102              617    2570425    4166.004862             2227
# 103              310    2642380    8523.806452             1669
# 104              715    1310440    1832.783217             1552
# 105              530    2862995    5401.877358             1637
# 106              411    1444025    3513.442822             1781
# 107              597    1973805    3306.206030             2052
# 108              676    2600915    3847.507396             2497
# 109              617    1961240    3178.670989             2247
# 110              774    2067720    2671.472868             1985
# 111              676    2276575    3367.714497             1992
# 112              554    1322790    2387.707581             1268
# 113              617    2608740    4228.103728             2738
# 114              588    2565235    4362.644558              921
# 115              676    2100715    3107.566568             2077
# 116              411    2200580    5354.209246             1922
# 117              637    3084455    4842.158556             2577
# 118              513    2131345    4154.668616             2480
# 119              527    1128935    2142.191651             1083
# 120              411    2399125    5837.287105             1778
# 121              699    2110800    3019.742489             1746
# 122              597    3023805    5065.000000             2832
# 123              676    1325070    1960.162722             1423
#
#      single_day_max_vol  single_day_min_vol
# 100              416450                9805
# 101               63695                6210
# 102              179010               11240
# 103              379995                9530
# 104               83410                5465
# 105              255825                5845
# 106               84285                5045
# 107               79130                8220
# 108              221065                8605
# 109              250855               11600
# 110              378050                8590
# 111              215975                6320
# 112              148920                2130
# 113              133130               15690
# 114              262085                4250
# 115              203600                6760
# 116              126685                4630
# 117              170700                8665
# 118              185500                6060
# 119              119750                2160
# 120              157410                8015
# 121              475215                6495
# 122              162465               16780
# 123               84500                5495

# %%
FinalPred = FinalModel.predict(test_shops)

# %%
len(FinalPred)
# Out:
# 24

# %% [markdown]
# ## Combining predictions with shop_id

# %%
# Create a dictionary mapping the old values to the new values
mapping = {0: 'Low', 1: 'Moderate', 2: 'High'}

# Map the values in the 'shop_profile' column using the dictionary
testdata["shop_profile"] = FinalPred

# %%
testdata
# Out:
#     shop_id  shop_profile
# 0   SHOP046             2
# 1   SHOP024             0
# 2   SHOP023             0
# 3   SHOP097             1
# 4   SHOP044             1
# 5   SHOP030             1
# 6   SHOP038             0
# 7   SHOP029             1
# 8   SHOP096             1
# 9   SHOP092             1
# 10  SHOP081             2
# 11  SHOP076             1
# 12  SHOP080             0
# 13  SHOP074             2
# 14  SHOP107             1
# 15  SHOP108             0
# 16  SHOP019             1
# 17  SHOP002             1
# 18  SHOP114             0
# 19  SHOP087             0
# 20  SHOP050             1
# 21  SHOP061             2
# 22  SHOP056             2
# 23  SHOP070             0

# %%
# Define a dictionary to map values to labels
label_map = {0: 'Low', 1: 'Moderate', 2: 'High'}

# Replace the values in the shop_profile column with labels
testdata['shop_profile'] = testdata['shop_profile'].replace(label_map)

# %%
## Write to CSV
testdata.to_csv('output.csv', index=False)
